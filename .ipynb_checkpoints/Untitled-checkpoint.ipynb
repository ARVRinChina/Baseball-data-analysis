# %%
数据表中有以下信息

明星登记 与薪资的关系?  是否等级越高, 薪资越高
明星 与学校排名的关系?
明星和外观的关系?
球员奖金 和 等级关系

2.1 MASTER表
2.5全明星表   All-Star table
2.15薪金表    Salaries table
2.18奖项玩家表   AwardsPlayers table
2.20奖项Share球员表  SwardsSharePlayers table
2.22外观表    Appearances table
2.23学校表    Schools table
2.24学校玩家表 SchoolsPlayer table

2.0数据表

设计遵循这些一般原则。 每个玩家被分配一个
唯一编号（playerID）。 所有与该玩家有关的信息
标有他的playerID。 playerID与名称和
MASTER表中的生日。


AllStarFull - 全明星出场
   HallofFame - 名人堂投票数据
   经理 - 管理统计
   球队 - 每年统计和排名
   击球后 - 击球后统计数据
   PitchingPost - 赛季后投球统计
   TeamFranchises - 特许经营信息
   FieldingOF - 外场位置数据
   FieldingPost-赛季后场数据
   经理人半场 - 为经理分配赛季数据
   球队半场 - 为球队分配赛季数据
   薪金 - 球员工资数据
   SeriesPost - 赛季后系列信息
   奖项管理员 - 获奖者由经理人员
   AwardsPlayers - 获奖者获得的奖项
   AwardsShareManagers - 获奖经理奖投票
   AwardsSharePlayers - 获得球员奖项的投票
   外观 - 玩家出现的位置细节
   学校 - 球员出席的大学名单
   CollegePlaying - 球员名单和他们参加的大学
    
    
2.24 CollegePlaying表
playerid播放器ID代码
schoolID学校ID代码
年

2.23 Schools table
schoolID       school ID code
schoolName     school name
schoolCity     city where school is located
schoolState    state where school's city is located
schoolNick     nickname for school's baseball team

2.22外观表

yearID年
teamID团队
lgID联赛
playerID播放器ID代码
G_all总共玩过的游戏
GS Games开始了
G_batting玩家击中的游戏
G_defense玩家出现在防守中的游戏
G_p比赛作为投手
G_c比赛作为捕手
G_1b比赛作为firstbaseman
G_2b比赛作为二垒手
G_3b比赛作为三垒手
G_ss游戏作为游击手
G_lf作为左场的比赛
G_cf比赛作为中场
G_rf Games作为右外野手
G_of作为外野手的比赛
G_dh比赛作为指定的击球手
G_ph游戏作为捏手击球手
G_pr比赛作为捏跑者


2.1 MASTER表


playerID分配给每个玩家的唯一代码。 playerID链接
                 该文件中的数据与其他文件中的记录。
出生年份球员出生
生日月球员出生
birthDay Day球员诞生了
birthCountry玩家出生的国家
birthState玩家出生的状态
生日城市玩家出生的城市
死亡年球员死亡
死亡月球员死亡
死亡日球员死亡
deathCountry玩家去世的国家
死亡状态玩家死亡的地方
死亡城市玩家死亡的地方
nameFirst Player的名字
nameLast Player的姓氏
nameGiven Player的名字（通常是第一个和中间）
体重以磅为单位的球员体重
身高球员身高（英寸）
蝙蝠玩家的击球手（左，右，或两者）
抛出玩家的手牌（左或右）
首次亮相球员首次大联盟亮相的日期
finalGame球员首次参加大联盟的日期（如果仍然有效，则为空）
retrosheet使用的retroID ID
棒球参考网站使用的bbrefID ID
